# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ks_2samp, epps_singleton_2samp
import matplotlib.patches as mpatches

# %% [markdown]
# ----------------------

# %% [markdown]
# # Top-level view of SD2 protein design data

# %% [markdown]
# ----------------------

# %%
#show total number of entries, topologies used
data = pd.read_csv('./data/df_aggregated_spc.csv')

#NTF2 topology should not be used so remove those rows (stability score does not map equally to other topologies)
ntf2_inx = data[data['topology']=='NTF2'].index 
data = data.drop(ntf2_inx)

print("Total number of entries --> %s"%len(data))
print("Total number of topologies --> %s"%len(data.topology.unique()))
print("")

# define rosetta features
ros_features = pd.read_csv('./data/rosetta_features.csv')['0'].to_list()

# define entropy features
spc_features = pd.read_csv('./data/entropy_features.csv')["0"].to_list()

# define stability ('stable'/'unstable')
data['stabilityscore_cnn_calibrated_2classes'] = data['stabilityscore_cnn_calibrated'] > 1
stable_proteins = data[data['stabilityscore_cnn_calibrated_2classes']==1]
unstable_proteins = data[data['stabilityscore_cnn_calibrated_2classes']==0]
# Out:
# Total number of entries --> 80257
# Total number of topologies --> 11

# %%
a = 8
plt.figure(figsize=(a*1.618,a))






(markers, stemlines, baseline) = plt.stem(
        data["topology"].value_counts().index,
        data["topology"].value_counts(),
        linefmt="--",
        markerfmt="o")

plt.setp(markers, marker=11, markersize=20, markeredgewidth=2,color='black')
plt.setp(stemlines,color='black')

plt.ylim(0)
plt.xticks(rotation=45,fontsize='20')
plt.yticks(fontsize="20")
plt.ylabel("Protein count",fontsize="32")
plt.savefig("./SavedFigures/StemPlot.png",dpi=1200,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Visualize Features for Classification

# %%
from HelperFunctions.feature_visualizations import show_all_plots

# %%
plt.rc('font', family='serif') # change font types for plots
plt.rc('xtick', labelsize='medium')
plt.rc('ytick', labelsize='medium')

# %% [markdown]
# ## Topology-unspecified

# %%
# show boxplot of all features (dataframe_visualizations/SD2 Feature Visualizations)
show_all_plots(data=data, 
               features=spc_features, 
               target='stabilityscore_cnn_calibrated_2classes',
               title_name='All proteins')
# Out:
# Number of Unstable: 68715
# number of Stable: 11542

# %% [markdown]
# ## Topology-specified

# %%
#show plots for all features per topology

#get a list of topologies
topologies_list = list(data['topology'].unique())

for topology in topologies_list:
    print("--------- Distributions for %s topology ----------"%topology)
    
    #subset the data to specify for a topology
    df = data[data['topology']==topology]
    
    #plot distributions for subset
    show_all_plots(data=df, 
               features=spc_features, 
               target='stabilityscore_cnn_calibrated_2classes',
               title_name='%s'%topology)
# Out:
# --------- Distributions for 4h topology ----------
# Number of Unstable: 13226
# number of Stable: 1466
# --------- Distributions for ferredoxin topology ----------
# Number of Unstable: 13263
# number of Stable: 1122
# --------- Distributions for beta_grasp topology ----------
# Number of Unstable: 2268
# number of Stable: 106
# --------- Distributions for thio topology ----------
# Number of Unstable: 1997
# number of Stable: 49
# --------- Distributions for fold2 topology ----------
# Number of Unstable: 582
# number of Stable: 75
# --------- Distributions for coil topology ----------
# Number of Unstable: 547
# number of Stable: 26
# --------- Distributions for fold4 topology ----------
# Number of Unstable: 237
# number of Stable: 18
# --------- Distributions for HHH topology ----------
# Number of Unstable: 7275
# number of Stable: 4741
# --------- Distributions for EEHEE topology ----------
# Number of Unstable: 9009
# number of Stable: 706
# --------- Distributions for EHEE topology ----------
# Number of Unstable: 5435
# number of Stable: 1210
# --------- Distributions for HEEH topology ----------
# Number of Unstable: 14876
# number of Stable: 2023

# %% [markdown]
# ----------------------

# %% [markdown]
# # Kolmogorov-Smirnov (KS) Test for 'stable' and 'unstable' distributions

# %% [markdown]
# ----------------------

# %% [markdown]
# ## Topology-unspecified

# %%
from scipy.stats import ks_2samp

# get KS values for all features
rows = []
for fet in spc_features:
    subset_stable = stable_proteins[fet]
    subset_unstable = unstable_proteins[fet]
    
    ks_value, p_value = ks_2samp(subset_stable,subset_unstable)
    rows.append([fet,ks_value,False,p_value]) #third row corresponds to 'is_rosetta' column

for fet in ros_features:
    subset_stable = stable_proteins[fet]
    subset_unstable = unstable_proteins[fet]
    
    ks_value, p_value = ks_2samp(subset_stable,subset_unstable)
    rows.append([fet,ks_value,True,p_value])

    
    
#make a dataframe from ks value data
ks_values_all = pd.DataFrame(rows,columns=['Feature','KS','is_rosetta','P-value'])

#subset for entropy feature ks values and rosetta feature ks values
ks_values_all_spc = ks_values_all[ks_values_all['is_rosetta']==False]
ks_values_all_ros = ks_values_all[ks_values_all['is_rosetta']==True]


#get index of row with highest ks value for entropy and rosetta feature subset
spc_max_inx = ks_values_all_spc['KS'].idxmax()
ros_max_inx = ks_values_all_ros['KS'].idxmax()

# %%
print("Entropy feature with highest KS Value:\n",ks_values_all.iloc[spc_max_inx,:])
print()
print("Rosetta feature with highest KS Value\n",ks_values_all.iloc[ros_max_inx,:])
# Out:
# Entropy feature with highest KS Value:
#  Feature       E_max_entropy
# KS                 0.233719
# is_rosetta            False
# P-value                   0
# Name: 14, dtype: object
#
# Rosetta feature with highest KS Value
#  Feature       avg_best_frag
# KS                 0.361311
# is_rosetta             True
# P-value                   0
# Name: 27, dtype: object

# %% [markdown]
# E_max_entropy is technically the largest KS value feature, but this difference is due to the fact that proteins which did not contain a beta sheet (i.e. HHH topology proteins) were filled in with a value of 0 for the beta sheet features.
#
# The next highest, non-beta-sheet-feature KS value was L_min_entropy, which all proteins contain.

# %%
golden = (1 + 5 ** 0.5) / 2
fets = ['L_min_entropy','avg_best_frag']

f, __ = plt.subplots(0,0,figsize=[5*golden,5],subplot_kw={"aspect":golden})

fet = fets[0]
sns.kdeplot(data=stable_proteins[fet],label='stable',shade=True,color='darkorange')
sns.kdeplot(data=unstable_proteins[fet],label='unstable',shade=True,color='dodgerblue')
ax = plt.gca()
ax.set_xlabel("%s"%(fet),fontsize='16')

plt.gcf()

f, __ = plt.subplots(0,0,figsize=[5*golden,5],subplot_kw={"aspect":golden})

fet = fets[1]
sns.kdeplot(data=stable_proteins[fet],label='stable',shade=True,color='darkorange')
sns.kdeplot(data=unstable_proteins[fet],label='unstable',shade=True,color='dodgerblue')
ax = plt.gca()
ax.set_xlabel("%s"%(fet),fontsize='16')

plt.show()

# %%
# show entropy features ranked by KS value
ks_values_all_spc[ks_values_all_spc['P-value']<.05].sort_values(by='KS',ascending=False)
# Out:
#              Feature        KS  is_rosetta        P-value
# 16   E_range_entropy  0.233719       False   0.000000e+00
# 14     E_max_entropy  0.233719       False   0.000000e+00
# 15     E_min_entropy  0.233253       False   0.000000e+00
# 3     Mean_E_entropy  0.219145       False   0.000000e+00
# 7     SumE_entropies  0.219145       False   0.000000e+00
# 12     L_min_entropy  0.184505       False  1.264329e-292
# 2     Mean_L_entropy  0.161355       False  6.686678e-224
# 10   H_range_entropy  0.144643       False  5.250187e-180
# 8      H_max_entropy  0.135258       False  1.859491e-157
# 0               S_PC  0.105591       False   3.975463e-96
# 4   Mean_res_entropy  0.101095       False   3.761390e-88
# 13   L_range_entropy  0.092948       False   1.397498e-74
# 9      H_min_entropy  0.079753       False   5.071219e-55
# 5     SumH_entropies  0.076376       False   1.704570e-50
# 6     SumL_entropies  0.034517       False   1.187073e-10
# 11     L_max_entropy  0.031086       False   1.015233e-08
# 1     Mean_H_entropy  0.029384       False   7.764462e-08

# %% [markdown]
# Full list of KS values for Rosetta features

# %%
print(ks_values_all_ros.sort_values(by="KS",ascending=False).to_string())
# Out:
#                         Feature        KS  is_rosetta        P-value
# 27                avg_best_frag  0.361311        True   0.000000e+00
# 26                avg_all_frags  0.354210        True   0.000000e+00
# 89         mismatch_probability  0.324384        True   0.000000e+00
# 128                 worst6frags  0.287130        True   0.000000e+00
# 124              sum_best_frags  0.283294        True   0.000000e+00
# 25    abego_res_profile_penalty  0.279034        True   0.000000e+00
# 129                   worstfrag  0.278745        True   0.000000e+00
# 103             net_atr_per_res  0.278246        True   0.000000e+00
# 55               fa_atr_per_res  0.269890        True   0.000000e+00
# 81                     hxl_tors  0.262143        True   0.000000e+00
# 107                  nres_helix  0.253138        True   0.000000e+00
# 121               score_per_res  0.248123        True   0.000000e+00
# 75                  hbond_sr_bb  0.247241        True   0.000000e+00
# 36            buried_np_per_res  0.241876        True   0.000000e+00
# 67                   frac_helix  0.240630        True   0.000000e+00
# 108                   nres_loop  0.236987        True   0.000000e+00
# 73        hbond_lr_bb_per_sheet  0.233719        True   0.000000e+00
# 109                  nres_sheet  0.233719        True   0.000000e+00
# 69                   frac_sheet  0.233719        True   0.000000e+00
# 28                           bb  0.226995        True   0.000000e+00
# 72                  hbond_lr_bb  0.224801        True   0.000000e+00
# 127               two_core_each  0.223742        True   0.000000e+00
# 60          fa_intra_atr_xover4  0.220976        True   0.000000e+00
# 123                       ss_sc  0.210788        True   0.000000e+00
# 88                      loop_sc  0.210719        True   0.000000e+00
# 35   buried_np_AFILMVWY_per_res  0.207546        True   0.000000e+00
# 51          exposed_np_AFILMVWY  0.205451        True   0.000000e+00
# 20                    Tend_absq  0.198512        True   0.000000e+00
# 39      chymo_with_LM_cut_sites  0.194960        True   0.000000e+00
# 61                fa_intra_elec  0.194651        True   0.000000e+00
# 68                    frac_loop  0.182936        True  1.123468e-287
# 104             net_sol_per_res  0.178206        True  5.152596e-273
# 79            hphob_sc_contacts  0.177846        True  6.509615e-272
# 117                 rama_prepro  0.177775        True  1.069206e-271
# 22                 Tminus1_absq  0.177594        True  3.820848e-271
# 18                      T1_absq  0.176715        True  1.791279e-268
# 21                    Tend_netq  0.169520        True  4.322640e-247
# 83        largest_hphob_cluster  0.168500        True  3.940183e-244
# 54                       fa_atr  0.165718        True  3.772877e-236
# 62          fa_intra_rep_xover4  0.164992        True  4.340436e-234
# 43            contig_not_hp_avg  0.162338        True  1.242506e-226
# 44       contig_not_hp_avg_norm  0.161860        True  2.666841e-225
# 19                      T1_netq  0.157695        True  7.052885e-214
# 82               hydrophobicity  0.149462        True  3.585311e-192
# 77                     helix_sc  0.147639        True  1.600798e-187
# 85               lk_ball_bridge  0.139681        True  6.781804e-168
# 33                    buried_np  0.139337        True  4.519618e-167
# 126              tryp_cut_sites  0.137059        True  1.146833e-161
# 93            n_hydrophobic_noA  0.132192        True  2.030558e-150
# 57                   fa_dun_rot  0.129300        True  6.270059e-144
# 23                 Tminus1_netq  0.128427        True  5.372095e-142
# 80              hphob_sc_degree  0.127013        True  6.749358e-139
# 90                    n_charged  0.116858        True  1.220251e-117
# 29                buns_bb_heavy  0.115703        True  2.468853e-115
# 125                 total_score  0.112541        True  3.861918e-109
# 111               one_core_each  0.111301        True  9.323450e-107
# 76        hbond_sr_bb_per_helix  0.110624        True  1.815324e-105
# 112                     p_aa_pp  0.110016        True  2.568403e-104
# 17                     AlaCount  0.107701        True  5.464773e-100
# 24            abego_res_profile  0.106896        True   1.658264e-98
# 86         lk_ball_bridge_uncpl  0.106021        True   6.577933e-97
# 46            contig_not_hp_max  0.103385        True   3.600768e-92
# 45   contig_not_hp_internal_max  0.101767        True   2.542122e-89
# 71                  hbond_bb_sc  0.096184        True   7.787016e-80
# 87                  lk_ball_iso  0.094902        True   9.865092e-78
# 94                 n_polar_core  0.094101        True   1.968410e-76
# 66                       fa_sol  0.093734        True   7.704064e-76
# 102     net_atr_net_sol_per_res  0.091733        True   1.179434e-72
# 34           buried_np_AFILMVWY  0.089728        True   1.566684e-69
# 50         exposed_hydrophobics  0.089546        True   2.979094e-69
# 84                      lk_ball  0.087402        True   5.383303e-66
# 118                         ref  0.085298        True   7.069054e-63
# 41            contact_core_SASA  0.084706        True   5.171218e-62
# 42             contact_core_SCN  0.084706        True   5.171218e-62
# 40                  contact_all  0.084706        True   5.171218e-62
# 95                        n_res  0.080867        True   1.475443e-56
# 106                        nres  0.080867        True   1.475443e-56
# 63          fa_intra_sol_xover4  0.080479        True   5.094668e-56
# 116                   pro_close  0.079627        True   7.545884e-55
# 78                        holes  0.078205        True   6.375656e-53
# 110                       omega  0.076760        True   5.320670e-51
# 91             n_hphob_clusters  0.072352        True   2.331677e-45
# 105                   netcharge  0.071475        True   2.823864e-44
# 53                exposed_total  0.069683        True   4.190590e-42
# 30                buns_nonheavy  0.068262        True   2.017558e-40
# 92                n_hydrophobic  0.067880        True   5.640057e-40
# 99    nearest_tryp_cut_to_Cterm  0.066917        True   7.331736e-39
# 115            percent_core_SCN  0.064921        True   1.330670e-36
# 37          buried_over_exposed  0.063954        True   1.562645e-35
# 119         res_count_core_SASA  0.061413        True   8.474252e-33
# 56                   fa_dun_dev  0.060567        True   6.504004e-32
# 120          res_count_core_SCN  0.056704        True   5.041776e-28
# 97   nearest_chymo_cut_to_Nterm  0.056126        True   1.826668e-27
# 70            fxn_exposed_is_np  0.054309        True   9.636124e-26
# 100   nearest_tryp_cut_to_Nterm  0.051430        True   3.956004e-23
# 32         buried_minus_exposed  0.049720        True   1.207426e-21
# 47                       degree  0.048144        True   2.546997e-20
# 65               fa_rep_per_res  0.047667        True   6.283071e-20
# 122         ss_contributes_core  0.044147        True   3.734038e-17
# 58                  fa_dun_semi  0.042149        True   1.128293e-15
# 31                buns_sc_heavy  0.039569        True   7.273182e-14
# 98    nearest_chymo_cut_to_term  0.037793        True   1.099316e-12
# 101    nearest_tryp_cut_to_term  0.036975        True   3.682398e-12
# 114           percent_core_SASA  0.036960        True   3.762599e-12
# 52               exposed_polars  0.035415        True   3.429845e-11
# 74                     hbond_sc  0.033607        True   4.042786e-10
# 59                      fa_elec  0.033455        True   4.945767e-10
# 38              chymo_cut_sites  0.033121        True   7.676279e-10
# 113                        pack  0.032517        True   1.680086e-09
# 96   nearest_chymo_cut_to_Cterm  0.029738        True   5.128953e-08
# 64                       fa_rep  0.028141        True   3.189787e-07
# 48                    dslf_fa13 -0.000000        True   1.000000e+00
# 49                      entropy -0.000000        True   1.000000e+00

# %%
ks_values_all_ros[ks_values_all_ros["KS"]>0.184505]["Feature"].to_csv("./data/subset_rosetta_features.csv",index=False)

# %% [markdown]
# ## Topology-specified

# %% [markdown]
# ## N.B.:
# * not all entropy features are showing for each topology because we are only showing those with p_value < .05
#
# * **IMPORTANT**: SciPy _needs_ to be version 1.3.0, since its `ks_2samp` function is more accurate than the 1.2.x version I was previously using

# %%
rows = []

for topology in topologies_list:
    stable_top_specific = stable_proteins[stable_proteins['topology']==topology]
    unstable_top_specific = unstable_proteins[unstable_proteins['topology']==topology]
    

    for fet in spc_features:
        subset_stable = stable_top_specific[fet]
        subset_unstable = unstable_top_specific[fet]

        ks_value, p_value = ks_2samp(subset_stable,subset_unstable)
        rows.append([fet,ks_value,False,topology,p_value]) #third row corresponds to 'is_rosetta' column

    for fet in ros_features:
        subset_stable = stable_top_specific[fet]
        subset_unstable = unstable_top_specific[fet]

        ks_value, p_value = ks_2samp(subset_stable,subset_unstable)
        rows.append([fet,ks_value,True,topology,p_value])

# %%
ks_values_topology = pd.DataFrame(rows,columns=['Feature','KS','is_rosetta','topology','P-value'])
ks_values_topology_spc = ks_values_topology[ks_values_topology['is_rosetta']==False].reset_index(drop=True)
ks_values_topology_ros = ks_values_topology[ks_values_topology['is_rosetta']==True].reset_index(drop=True)

# %%
#show entropy features ranked by KS value for each topology.
df = ks_values_topology_spc[ks_values_topology_spc['P-value']<.05].sort_values(by='KS',ascending=False)
for topology in topologies_list:
    print("\t TOPOLOGY --> %s"%topology)
    print(df[df['topology']==topology])
    print()
# Out:
# 	 TOPOLOGY --> 4h
#              Feature        KS  is_rosetta topology       P-value
# 5     SumH_entropies  0.115372       False       4h  1.104171e-15
# 1     Mean_H_entropy  0.114603       False       4h  1.760869e-15
# 0               S_PC  0.089316       False       4h  1.434538e-09
# 4   Mean_res_entropy  0.086368       False       4h  5.626970e-09
# 9      H_min_entropy  0.085904       False       4h  6.948911e-09
# 10   H_range_entropy  0.046820       False       4h  6.141417e-03
# 12     L_min_entropy  0.041484       False       4h  2.129706e-02
#
# 	 TOPOLOGY --> ferredoxin
#              Feature        KS  is_rosetta    topology       P-value
# 27   H_range_entropy  0.111798       False  ferredoxin  1.175939e-11
# 22    SumH_entropies  0.095049       False  ferredoxin  1.524946e-08
# 20    Mean_E_entropy  0.092258       False  ferredoxin  4.498617e-08
# 26     H_min_entropy  0.091111       False  ferredoxin  6.949401e-08
# 33   E_range_entropy  0.089613       False  ferredoxin  1.216890e-07
# 24    SumE_entropies  0.086504       False  ferredoxin  3.778487e-07
# 19    Mean_L_entropy  0.086114       False  ferredoxin  4.342707e-07
# 21  Mean_res_entropy  0.084972       False  ferredoxin  6.507108e-07
# 29     L_min_entropy  0.083986       False  ferredoxin  9.183743e-07
# 32     E_min_entropy  0.079926       False  ferredoxin  3.639007e-06
# 18    Mean_H_entropy  0.078884       False  ferredoxin  5.125204e-06
# 17              S_PC  0.077467       False  ferredoxin  8.105109e-06
# 23    SumL_entropies  0.065459       False  ferredoxin  2.824451e-04
# 25     H_max_entropy  0.053013       False  ferredoxin  5.967286e-03
# 28     L_max_entropy  0.047862       False  ferredoxin  1.748377e-02
# 31     E_max_entropy  0.044779       False  ferredoxin  3.156998e-02
#
# 	 TOPOLOGY --> beta_grasp
#            Feature        KS  is_rosetta    topology   P-value
# 39  SumH_entropies  0.139879       False  beta_grasp  0.034215
# 35  Mean_H_entropy  0.139871       False  beta_grasp  0.034230
#
# 	 TOPOLOGY --> thio
#            Feature        KS  is_rosetta topology   P-value
# 60   H_min_entropy  0.242353       False     thio  0.005852
# 52  Mean_H_entropy  0.198532       False     thio  0.039574
#
# 	 TOPOLOGY --> fold2
#              Feature        KS  is_rosetta topology   P-value
# 71    Mean_E_entropy  0.206254       False    fold2  0.005855
# 75    SumE_entropies  0.200275       False    fold2  0.008159
# 73    SumH_entropies  0.195601       False    fold2  0.010501
# 69    Mean_H_entropy  0.184399       False    fold2  0.018765
# 72  Mean_res_entropy  0.179381       False    fold2  0.024050
# 68              S_PC  0.178144       False    fold2  0.025542
#
# 	 TOPOLOGY --> coil
#              Feature        KS  is_rosetta topology   P-value
# 89  Mean_res_entropy  0.357826       False     coil  0.002385
# 85              S_PC  0.334130       False     coil  0.005648
# 90    SumH_entropies  0.288286       False     coil  0.025440
# 86    Mean_H_entropy  0.286458       False     coil  0.026873
#
# 	 TOPOLOGY --> fold4
#            Feature        KS  is_rosetta topology  P-value
# 110  H_max_entropy  0.336146       False    fold4  0.03459
#
# 	 TOPOLOGY --> HHH
# Empty DataFrame
# Columns: [Feature, KS, is_rosetta, topology, P-value]
# Index: []
#
# 	 TOPOLOGY --> EEHEE
#               Feature        KS  is_rosetta topology        P-value
# 143    SumE_entropies  0.421752       False    EEHEE  1.414491e-101
# 141    SumH_entropies  0.410102       False    EEHEE   4.588637e-96
# 137    Mean_H_entropy  0.409991       False    EEHEE   5.169506e-96
# 152   E_range_entropy  0.303562       False    EEHEE   7.928893e-53
# 144     H_max_entropy  0.274624       False    EEHEE   2.591900e-43
# 145     H_min_entropy  0.273839       False    EEHEE   4.555185e-43
# 151     E_min_entropy  0.264812       False    EEHEE   2.651936e-40
# 140  Mean_res_entropy  0.258531       False    EEHEE   1.962650e-38
# 139    Mean_E_entropy  0.250163       False    EEHEE   5.169702e-36
# 150     E_max_entropy  0.248600       False    EEHEE   1.434854e-35
# 148     L_min_entropy  0.222752       False    EEHEE   1.216008e-28
# 136              S_PC  0.159006       False    EEHEE   8.387494e-15
# 147     L_max_entropy  0.129361       False    EEHEE   6.093497e-10
# 149   L_range_entropy  0.123911       False    EEHEE   3.714489e-09
# 138    Mean_L_entropy  0.107039       False    EEHEE   6.104817e-07
# 142    SumL_entropies  0.096658       False    EEHEE   9.730536e-06
# 146   H_range_entropy  0.081575       False    EEHEE   3.287907e-04
#
# 	 TOPOLOGY --> EHEE
#             Feature        KS  is_rosetta topology       P-value
# 154  Mean_H_entropy  0.175689       False     EHEE  5.854359e-27
# 158  SumH_entropies  0.167024       False     EHEE  2.091536e-24
# 164   L_max_entropy  0.136030       False     EHEE  2.480836e-16
# 159  SumL_entropies  0.133068       False     EHEE  1.201709e-15
# 160  SumE_entropies  0.131479       False     EHEE  2.760484e-15
#
# 	 TOPOLOGY --> HEEH
#               Feature        KS  is_rosetta topology       P-value
# 174  Mean_res_entropy  0.208802       False     HEEH  7.299925e-68
# 175    SumH_entropies  0.185830       False     HEEH  7.681767e-54
# 170              S_PC  0.180820       False     HEEH  5.329771e-51
# 180   H_range_entropy  0.176285       False     HEEH  1.706404e-48
# 171    Mean_H_entropy  0.161161       False     HEEH  1.337477e-40
# 182     L_min_entropy  0.148002       False     HEEH  2.624720e-34
# 183   L_range_entropy  0.145385       False     HEEH  4.042000e-33
# 178     H_max_entropy  0.144721       False     HEEH  8.029688e-33
# 179     H_min_entropy  0.138382       False     HEEH  4.789943e-30
# 181     L_max_entropy  0.132154       False     HEEH  1.934352e-27
# 186   E_range_entropy  0.115818       False     HEEH  3.569837e-21
# 173    Mean_E_entropy  0.104341       False     HEEH  2.891003e-17
# 185     E_min_entropy  0.090990       False     HEEH  3.124920e-13
# 172    Mean_L_entropy  0.077403       False     HEEH  1.080969e-09
# 176    SumL_entropies  0.077128       False     HEEH  1.257751e-09
# 184     E_max_entropy  0.076853       False     HEEH  1.461829e-09
# 177    SumE_entropies  0.036162       False     HEEH  1.898156e-02

# %%
#show Rosetta features ranked by KS value for each topology.
df = ks_values_topology_ros[ks_values_topology_ros['P-value']<.05].sort_values(by='KS',ascending=False)
for topology in topologies_list:
    print("\t TOPOLOGY --> %s"%topology)
    print(df[df['topology']==topology].iloc[:20,:])
    print()
# Out:
# 	 TOPOLOGY --> 4h
#                         Feature        KS  is_rosetta topology        P-value
# 17           buried_np_AFILMVWY  0.448109        True       4h  1.329924e-230
# 18   buried_np_AFILMVWY_per_res  0.445253        True       4h  1.116334e-227
# 19            buried_np_per_res  0.421940        True       4h  1.669246e-204
# 76            n_hydrophobic_noA  0.412548        True       4h  1.607671e-195
# 62            hphob_sc_contacts  0.405712        True       4h  4.158524e-189
# 66        largest_hphob_cluster  0.401661        True       4h  2.329784e-185
# 65               hydrophobicity  0.391196        True       4h  7.563510e-176
# 104               score_per_res  0.384380        True       4h  8.683563e-170
# 38               fa_atr_per_res  0.364663        True       4h  7.377985e-153
# 108                 total_score  0.363574        True       4h  5.989553e-152
# 43          fa_intra_atr_xover4  0.353236        True       4h  1.867773e-143
# 24            contact_core_SASA  0.350866        True       4h  1.529818e-141
# 25             contact_core_SCN  0.350866        True       4h  1.529818e-141
# 23                  contact_all  0.350866        True       4h  1.529818e-141
# 75                n_hydrophobic  0.341067        True       4h  9.044621e-134
# 85      net_atr_net_sol_per_res  0.339894        True       4h  7.443628e-133
# 15         buried_minus_exposed  0.333545        True       4h  5.933641e-128
# 16                    buried_np  0.326432        True       4h  1.426716e-122
# 9                 avg_all_frags  0.322708        True       4h  8.430452e-120
# 26            contig_not_hp_avg  0.300928        True       4h  3.127160e-104
#
# 	 TOPOLOGY --> ferredoxin
#                         Feature        KS  is_rosetta    topology  \
# 130          buried_np_AFILMVWY  0.466921        True  ferredoxin
# 189           n_hydrophobic_noA  0.455416        True  ferredoxin
# 131  buried_np_AFILMVWY_per_res  0.448569        True  ferredoxin
# 178              hydrophobicity  0.428951        True  ferredoxin
# 132           buried_np_per_res  0.388025        True  ferredoxin
# 179       largest_hphob_cluster  0.387128        True  ferredoxin
# 156         fa_intra_atr_xover4  0.385202        True  ferredoxin
# 188               n_hydrophobic  0.384661        True  ferredoxin
# 139           contig_not_hp_avg  0.381417        True  ferredoxin
# 129                   buried_np  0.378114        True  ferredoxin
# 175           hphob_sc_contacts  0.376614        True  ferredoxin
# 150                      fa_atr  0.369673        True  ferredoxin
# 151              fa_atr_per_res  0.350945        True  ferredoxin
# 137           contact_core_SASA  0.342887        True  ferredoxin
# 136                 contact_all  0.342887        True  ferredoxin
# 138            contact_core_SCN  0.342887        True  ferredoxin
# 199             net_atr_per_res  0.332620        True  ferredoxin
# 128        buried_minus_exposed  0.322020        True  ferredoxin
# 198     net_atr_net_sol_per_res  0.305940        True  ferredoxin
# 221                 total_score  0.298041        True  ferredoxin
#
#            P-value
# 130  2.539516e-196
# 189  8.709078e-187
# 131  3.173094e-181
# 178  9.336152e-166
# 132  1.031867e-135
# 179  4.346991e-135
# 156  9.430764e-134
# 188  2.232077e-133
# 139  3.820229e-131
# 129  6.859318e-129
# 175  7.137998e-128
# 150  3.221248e-123
# 151  4.310796e-111
# 137  4.547460e-106
# 136  4.547460e-106
# 138  4.547460e-106
# 199  7.758823e-100
# 128   1.333073e-93
# 198   1.577305e-84
# 221   3.053100e-80
#
# 	 TOPOLOGY --> beta_grasp
#                         Feature        KS  is_rosetta    topology  \
# 245           buried_np_per_res  0.470051        True  beta_grasp
# 302           n_hydrophobic_noA  0.437897        True  beta_grasp
# 291              hydrophobicity  0.436799        True  beta_grasp
# 288           hphob_sc_contacts  0.429503        True  beta_grasp
# 292       largest_hphob_cluster  0.422107        True  beta_grasp
# 243          buried_np_AFILMVWY  0.406917        True  beta_grasp
# 244  buried_np_AFILMVWY_per_res  0.404895        True  beta_grasp
# 252           contig_not_hp_avg  0.400777        True  beta_grasp
# 249                 contact_all  0.371136        True  beta_grasp
# 251            contact_core_SCN  0.371136        True  beta_grasp
# 250           contact_core_SASA  0.371136        True  beta_grasp
# 269         fa_intra_atr_xover4  0.347592        True  beta_grasp
# 242                   buried_np  0.343192        True  beta_grasp
# 311     net_atr_net_sol_per_res  0.314241        True  beta_grasp
# 260         exposed_np_AFILMVWY  0.304208        True  beta_grasp
# 248     chymo_with_LM_cut_sites  0.297760        True  beta_grasp
# 330               score_per_res  0.297045        True  beta_grasp
# 312             net_atr_per_res  0.288351        True  beta_grasp
# 271         fa_intra_rep_xover4  0.283585        True  beta_grasp
# 264              fa_atr_per_res  0.283402        True  beta_grasp
#
#           P-value
# 245  1.110223e-16
# 302  1.110223e-16
# 291  1.110223e-16
# 288  1.110223e-16
# 292  1.110223e-16
# 243  1.665335e-15
# 244  1.887379e-15
# 252  3.996803e-15
# 249  5.176970e-13
# 251  5.176970e-13
# 250  5.176970e-13
# 269  1.986233e-11
# 242  3.809453e-11
# 311  2.223307e-09
# 260  8.263200e-09
# 248  1.883042e-08
# 330  2.062985e-08
# 312  6.018096e-08
# 271  1.069576e-07
# 264  1.093895e-07
#
# 	 TOPOLOGY --> thio
#                         Feature        KS  is_rosetta topology       P-value
# 382         fa_intra_atr_xover4  0.554199        True     thio  2.231548e-14
# 401           hphob_sc_contacts  0.482070        True     thio  9.794454e-11
# 405       largest_hphob_cluster  0.468928        True     thio  3.745441e-10
# 357  buried_np_AFILMVWY_per_res  0.440743        True     thio  5.719878e-09
# 358           buried_np_per_res  0.418608        True     thio  4.197491e-08
# 415           n_hydrophobic_noA  0.414571        True     thio  5.987819e-08
# 404              hydrophobicity  0.412834        True     thio  6.958888e-08
# 411        mismatch_probability  0.407315        True     thio  1.114878e-07
# 356          buried_np_AFILMVWY  0.407070        True     thio  1.138478e-07
# 365           contig_not_hp_avg  0.403687        True     thio  1.513838e-07
# 348               avg_all_frags  0.386406        True     thio  6.218575e-07
# 377              fa_atr_per_res  0.378527        True     thio  1.156874e-06
# 349               avg_best_frag  0.363351        True     thio  3.666238e-06
# 364            contact_core_SCN  0.351486        True     thio  8.723339e-06
# 363           contact_core_SASA  0.351486        True     thio  8.723339e-06
# 362                 contact_all  0.351486        True     thio  8.723339e-06
# 424     net_atr_net_sol_per_res  0.346510        True     thio  1.236107e-05
# 414               n_hydrophobic  0.344731        True     thio  1.406648e-05
# 393                 hbond_bb_sc  0.344231        True     thio  1.456846e-05
# 446              sum_best_frags  0.340695        True     thio  1.863838e-05
#
# 	 TOPOLOGY --> fold2
#                         Feature        KS  is_rosetta topology       P-value
# 517              hydrophobicity  0.431065        True    fold2  1.081923e-11
# 486         exposed_np_AFILMVWY  0.419450        True    fold2  4.510858e-11
# 470  buried_np_AFILMVWY_per_res  0.397388        True    fold2  6.059918e-10
# 537     net_atr_net_sol_per_res  0.382749        True    fold2  3.082338e-09
# 469          buried_np_AFILMVWY  0.357801        True    fold2  4.206786e-08
# 528           n_hydrophobic_noA  0.343780        True    fold2  1.666931e-07
# 527               n_hydrophobic  0.334158        True    fold2  4.184293e-07
# 556               score_per_res  0.298488        True    fold2  9.701275e-06
# 553                         ref  0.285911        True    fold2  2.678969e-05
# 467        buried_minus_exposed  0.278900        True    fold2  4.626689e-05
# 560                 total_score  0.277526        True    fold2  5.150458e-05
# 523                     loop_sc  0.276907        True    fold2  5.399840e-05
# 472         buried_over_exposed  0.266873        True    fold2  1.144801e-04
# 490              fa_atr_per_res  0.260481        True    fold2  1.821494e-04
# 558                       ss_sc  0.254433        True    fold2  2.795958e-04
# 495         fa_intra_atr_xover4  0.247354        True    fold2  4.561214e-04
# 514           hphob_sc_contacts  0.246735        True    fold2  4.751884e-04
# 471           buried_np_per_res  0.238900        True    fold2  8.011750e-04
# 489                      fa_atr  0.231409        True    fold2  1.299063e-03
# 538             net_atr_per_res  0.229347        True    fold2  1.479531e-03
#
# 	 TOPOLOGY --> coil
#                         Feature        KS  is_rosetta topology       P-value
# 583  buried_np_AFILMVWY_per_res  0.562649        True     coil  6.749961e-08
# 641           n_hydrophobic_noA  0.524258        True     coil  7.520616e-07
# 582          buried_np_AFILMVWY  0.505977        True     coil  2.188016e-06
# 630              hydrophobicity  0.489664        True     coil  5.309272e-06
# 669               score_per_res  0.469343        True     coil  1.621321e-05
# 591           contig_not_hp_avg  0.460554        True     coil  2.424772e-05
# 650     net_atr_net_sol_per_res  0.445577        True     coil  5.363038e-05
# 651             net_atr_per_res  0.442202        True     coil  6.085368e-05
# 584           buried_np_per_res  0.434608        True     coil  9.083524e-05
# 606                 fa_dun_semi  0.416608        True     coil  2.020272e-04
# 599         exposed_np_AFILMVWY  0.414921        True     coil  2.166785e-04
# 572           abego_res_profile  0.394108        True     coil  5.633749e-04
# 672              sum_best_frags  0.390240        True     coil  6.585023e-04
# 673                 total_score  0.385248        True     coil  8.059043e-04
# 575               avg_best_frag  0.382928        True     coil  8.920951e-04
# 603              fa_atr_per_res  0.380115        True     coil  9.674906e-04
# 627           hphob_sc_contacts  0.374561        True     coil  1.214799e-03
# 676                 worst6frags  0.373787        True     coil  1.292005e-03
# 610         fa_intra_rep_xover4  0.356138        True     coil  2.514272e-03
# 631       largest_hphob_cluster  0.346435        True     coil  3.694221e-03
#
# 	 TOPOLOGY --> fold4
#                         Feature        KS  is_rosetta topology   P-value
# 697           buried_np_per_res  0.601969        True    fold4  0.000003
# 721         fa_intra_atr_xover4  0.575246        True    fold4  0.000010
# 694                   buried_np  0.571027        True    fold4  0.000012
# 693        buried_minus_exposed  0.571027        True    fold4  0.000012
# 695          buried_np_AFILMVWY  0.563291        True    fold4  0.000017
# 703            contact_core_SCN  0.556259        True    fold4  0.000022
# 702           contact_core_SASA  0.556259        True    fold4  0.000022
# 701                 contact_all  0.556259        True    fold4  0.000022
# 763     net_atr_net_sol_per_res  0.527426        True    fold4  0.000075
# 715                      fa_atr  0.521097        True    fold4  0.000099
# 696  buried_np_AFILMVWY_per_res  0.504219        True    fold4  0.000191
# 743              hydrophobicity  0.500000        True    fold4  0.000224
# 712         exposed_np_AFILMVWY  0.458509        True    fold4  0.000993
# 698         buried_over_exposed  0.444444        True    fold4  0.001600
# 764             net_atr_per_res  0.431083        True    fold4  0.002461
# 724         fa_intra_sol_xover4  0.428973        True    fold4  0.002627
# 744       largest_hphob_cluster  0.419831        True    fold4  0.003498
# 716              fa_atr_per_res  0.419128        True    fold4  0.003577
# 754           n_hydrophobic_noA  0.403657        True    fold4  0.005695
# 753               n_hydrophobic  0.401547        True    fold4  0.006050
#
# 	 TOPOLOGY --> HHH
# Empty DataFrame
# Columns: [Feature, KS, is_rosetta, topology, P-value]
# Index: []
#
# 	 TOPOLOGY --> EEHEE
#                         Feature        KS  is_rosetta topology        P-value
# 930           contig_not_hp_avg  0.648746        True    EEHEE  9.290693e-240
# 938         exposed_np_AFILMVWY  0.635489        True    EEHEE  4.465466e-230
# 989     net_atr_net_sol_per_res  0.623621        True    EEHEE  1.404286e-221
# 931      contig_not_hp_avg_norm  0.611012        True    EEHEE  9.994632e-213
# 922  buried_np_AFILMVWY_per_res  0.604424        True    EEHEE  3.574334e-208
# 954                  frac_helix  0.596608        True    EEHEE  7.795400e-203
# 956                  frac_sheet  0.590365        True    EEHEE  1.274904e-198
# 913               avg_all_frags  0.581598        True    EEHEE  8.880083e-193
# 923           buried_np_per_res  0.581093        True    EEHEE  1.915177e-192
# 942              fa_atr_per_res  0.580630        True    EEHEE  3.872496e-192
# 996                  nres_sheet  0.563614        True    EEHEE  4.571765e-181
# 969              hydrophobicity  0.561268        True    EEHEE  1.448853e-179
# 970       largest_hphob_cluster  0.535318        True    EEHEE  2.200582e-163
# 914               avg_best_frag  0.532018        True    EEHEE  2.216909e-161
# 933           contig_not_hp_max  0.525683        True    EEHEE  1.431863e-157
# 932  contig_not_hp_internal_max  0.524035        True    EEHEE  1.379006e-156
# 980           n_hydrophobic_noA  0.514388        True    EEHEE  6.863636e-151
# 979               n_hydrophobic  0.509580        True    EEHEE  4.322993e-148
# 990             net_atr_per_res  0.506805        True    EEHEE  1.737590e-146
# 966           hphob_sc_contacts  0.503818        True    EEHEE  9.049723e-145
#
# 	 TOPOLOGY --> EHEE
#                          Feature        KS  is_rosetta topology        P-value
# 1035  buried_np_AFILMVWY_per_res  0.472666        True     EHEE  1.785984e-192
# 1082              hydrophobicity  0.468860        True     EHEE  2.149381e-189
# 1043           contig_not_hp_avg  0.460490        True     EHEE  1.043462e-182
# 1051         exposed_np_AFILMVWY  0.459153        True     EHEE  1.190471e-181
# 1102     net_atr_net_sol_per_res  0.424750        True     EHEE  1.642693e-155
# 1036           buried_np_per_res  0.376062        True     EHEE  5.394847e-122
# 1089        mismatch_probability  0.357204        True     EHEE  4.154434e-110
# 1079           hphob_sc_contacts  0.340459        True     EHEE  4.579043e-100
# 1083       largest_hphob_cluster  0.335392        True     EHEE   4.025262e-97
# 1104             net_sol_per_res  0.330550        True     EHEE   2.378945e-94
# 1093           n_hydrophobic_noA  0.310676        True     EHEE   2.144041e-83
# 1034          buried_np_AFILMVWY  0.304877        True     EHEE   2.509637e-80
# 1118                         ref  0.299053        True     EHEE   2.648976e-77
# 1092               n_hydrophobic  0.298906        True     EHEE   3.154237e-77
# 1066                      fa_sol  0.290047        True     EHEE   9.637749e-73
# 1084                     lk_ball  0.286943        True     EHEE   3.336586e-71
# 1125                 total_score  0.270553        True     EHEE   2.388828e-63
# 1121               score_per_res  0.270278        True     EHEE   3.204697e-63
# 1103             net_atr_per_res  0.269907        True     EHEE   4.765121e-63
# 1112                     p_aa_pp  0.256120        True     EHEE   8.173822e-57
#
# 	 TOPOLOGY --> HEEH
#                          Feature        KS  is_rosetta topology        P-value
# 1147          buried_np_AFILMVWY  0.463959        True     HEEH   0.000000e+00
# 1206           n_hydrophobic_noA  0.444153        True     HEEH  1.445433e-305
# 1205               n_hydrophobic  0.413535        True     HEEH  6.028480e-265
# 1146                   buried_np  0.401334        True     HEEH  1.443232e-249
# 1196       largest_hphob_cluster  0.390516        True     HEEH  2.564645e-236
# 1192           hphob_sc_contacts  0.361186        True     HEEH  3.255248e-202
# 1195              hydrophobicity  0.356070        True     HEEH  1.542781e-196
# 1145        buried_minus_exposed  0.347890        True     HEEH  1.245156e-187
# 1155            contact_core_SCN  0.344566        True     HEEH  4.523831e-184
# 1154           contact_core_SASA  0.344566        True     HEEH  4.523831e-184
# 1153                 contact_all  0.344566        True     HEEH  4.523831e-184
# 1173         fa_intra_atr_xover4  0.342293        True     HEEH  1.175571e-181
# 1175         fa_intra_rep_xover4  0.333274        True     HEEH  3.127848e-172
# 1215     net_atr_net_sol_per_res  0.322348        True     HEEH  3.761391e-161
# 1148  buried_np_AFILMVWY_per_res  0.321014        True     HEEH  7.987369e-160
# 1167                      fa_atr  0.313863        True     HEEH  8.414624e-153
# 1238                 total_score  0.305119        True     HEEH  1.984058e-144
# 1234               score_per_res  0.304557        True     HEEH  6.716021e-144
# 1156           contig_not_hp_avg  0.301005        True     HEEH  1.427616e-140
# 1149           buried_np_per_res  0.298703        True     HEEH  1.948575e-138

# %%
# Highest KS value for Entropy Feature in a topology:
spc_max_inx = ks_values_topology_spc['KS'].idxmax()

# %%
# Highest KS value for Rosetta Feature in a topology:
ros_max_inx = ks_values_topology_ros['KS'].idxmax()

# %%
print("Entropy feature-topology pair with highest KS Value:\n",ks_values_topology_spc.iloc[spc_max_inx,:])
print()
print("Rosetta feature-topology pair with highest KS Value\n",ks_values_topology_ros.iloc[ros_max_inx,:])
# Out:
# Entropy feature-topology pair with highest KS Value:
#  Feature       SumE_entropies
# KS                  0.421752
# is_rosetta             False
# topology               EEHEE
# P-value         1.41449e-101
# Name: 143, dtype: object
#
# Rosetta feature-topology pair with highest KS Value
#  Feature       contig_not_hp_avg
# KS                     0.648746
# is_rosetta                 True
# topology                  EEHEE
# P-value            9.29069e-240
# Name: 930, dtype: object

# %%
golden = (1 + 5 ** 0.5) / 2
fets = ['SumE_entropies','contig_not_hp_avg']
top = "EEHEE"

### show kde plots for figures

f, __ = plt.subplots(0,0,figsize=[5*golden,5],subplot_kw={"aspect":golden})

fet = fets[0]
sns.kdeplot(data=stable_proteins[stable_proteins['topology']==top][fet],label='stable',shade=True,color='darkorange')
sns.kdeplot(data=unstable_proteins[unstable_proteins['topology']==top][fet],label='unstable',shade=True,color='dodgerblue')
ax = plt.gca()
ax.set_xlabel("%s"%(fet),fontsize='16')

plt.savefig("./SavedFigures/Figure3d.png",dpi=300,bbox_anchor="tight")

f, __ = plt.subplots(0,0,figsize=[5*golden,5],subplot_kw={"aspect":golden})

fet = fets[1]
sns.kdeplot(data=stable_proteins[stable_proteins['topology']==top][fet],label='stable',shade=True,color='darkorange')
sns.kdeplot(data=unstable_proteins[unstable_proteins['topology']==top][fet],label='unstable',shade=True,color='dodgerblue')
ax = plt.gca()
ax.set_xlabel("%s"%(fet),fontsize='16')
plt.savefig("./SavedFigures/Figure3c.png",dpi=300,bbox_anchor="tight")


### show distributions for plots
fet = fets[0]
f, __ = plt.subplots(0,0,figsize=[5*golden,5],subplot_kw={"aspect":golden})
sns.distplot(data[fet].values,label="entire dataset",color='gray',kde=False)
sns.distplot(data[data['topology']==top][fet].values,label='EEHEE topology',color='green',kde=False)
ax = plt.gca()
ax.set_xlabel("%s"%(fet),fontsize='16')
plt.legend()
plt.savefig("./SavedFigures/Figure3e.png",dpi=300,bbox_anchor="tight")

fet = fets[1]
f, __ = plt.subplots(0,0,figsize=[5*golden,5],subplot_kw={"aspect":golden})
sns.distplot(data[fet].values,label="entire dataset",color='gray',kde=False)
sns.distplot(data[data['topology']==top][fet].values,label='EEHEE topology',color='green',kde=False)
ax = plt.gca()
ax.set_xlabel("%s"%(fet),fontsize='16')
plt.legend()
plt.savefig("./SavedFigures/Figure3f.png",dpi=300,bbox_anchor="tight")

plt.show()

# %% [markdown]
# ----------------------

# %% [markdown]
# # Epps-Singleton (ES) Test for 'stable' and 'unstable' distributions

# %% [markdown]
# ----------------------

# %% [markdown]
# ## Topology-unspecified

# %%
# get ES values for all features
rows = []
for fet in spc_features:
    try:
        subset_stable = stable_proteins[fet]
        subset_unstable = unstable_proteins[fet]

        es_value, p_value = epps_singleton_2samp(subset_stable,subset_unstable)
        rows.append([fet,es_value,False,p_value]) #third row corresponds to 'is_rosetta' column
    except:
        print("%s Feature did not work"%fet)
for fet in ros_features:
    try:
        subset_stable = stable_proteins[fet]
        subset_unstable = unstable_proteins[fet]
    
        es_value, p_value = epps_singleton_2samp(subset_stable,subset_unstable)
        rows.append([fet,es_value,True,p_value])
    except:
        print("%s Feature did not work"%fet)

# %%
#make a dataframe from ES value data
es_values_all = pd.DataFrame(rows,columns=['Feature','ES','is_rosetta','P-value'])

#subset for entropy feature ks values and rosetta feature ks values
es_values_all_spc = es_values_all[es_values_all['is_rosetta']==False]
es_values_all_ros = es_values_all[es_values_all['is_rosetta']==True]


#get index of row with highest ks value for entropy and rosetta feature subset
spc_max_inx = es_values_all_spc['ES'].idxmax()
ros_max_inx = es_values_all_ros['ES'].idxmax()

# %%
print("Entropy feature with highest ES Value:\n",es_values_all.iloc[spc_max_inx,:])
print()
print("Rosetta feature with highest ES Value\n",es_values_all.iloc[ros_max_inx,:])

# %%
# show entropy features ranked by ES value
es_values_all_spc[es_values_all_spc['P-value']<.05].sort_values(by='ES',ascending=False)

# %% [markdown]
# ## Topology-specified

# %% [markdown]
# ## N.B.:
# * not all entropy features are showing for each topology because we are only showing those with p_value < .05
#
# * **IMPORTANT**: SciPy _needs_ to be version 1.3.0, since its `epps_singleton_2samp` function is more accurate than the 1.2.x version I was previously using

# %%
rows = []

for topology in topologies_list:
    stable_top_specific = stable_proteins[stable_proteins['topology']==topology]
    unstable_top_specific = unstable_proteins[unstable_proteins['topology']==topology]
    
    #print("\t%s"%topology)
    for fet in spc_features:
        try:
            subset_stable = stable_top_specific[fet]
            subset_unstable = unstable_top_specific[fet]

            es_value, p_value = epps_singleton_2samp(subset_stable,subset_unstable)
            rows.append([fet,es_value,False,topology,p_value]) #third row corresponds to 'is_rosetta' column
        except:
            #print("%s Feature in %s topology did not work"%(fet,topology))
            pass
    print()
    for fet in ros_features:
        try:
            subset_stable = stable_top_specific[fet]
            subset_unstable = unstable_top_specific[fet]

            es_value, p_value = epps_singleton_2samp(subset_stable,subset_unstable)
            rows.append([fet,es_value,True,topology,p_value])
        except:
            #print("%s Feature in %s topology did not work"%(fet,topology))
            pass
    #print()
    #print()

es_values_topology = pd.DataFrame(rows,columns=['Feature','ES','is_rosetta','topology','P-value'])
es_values_topology_spc = es_values_topology[es_values_topology['is_rosetta']==False].reset_index(drop=True)
es_values_topology_ros = es_values_topology[es_values_topology['is_rosetta']==True].reset_index(drop=True)

#show entropy features ranked by KS value for each topology.
df = es_values_topology_spc[es_values_topology_spc['P-value']<.05].sort_values(by='ES',ascending=False)
for topology in topologies_list:
    print("\t TOPOLOGY --> %s"%topology)
    print(df[df['topology']==topology])
    print()

# %%
# Highest KS value for Entropy Feature in a topology:
spc_max_inx = es_values_topology_spc['ES'].idxmax()

# Highest KS value for Rosetta Feature in a topology:
ros_max_inx = es_values_topology_ros['ES'].idxmax()

print("Entropy feature with highest ES Value:\n",es_values_topology_spc.iloc[spc_max_inx,:])
print()
print("Rosetta feature with highest ES Value\n",es_values_topology_ros.iloc[ros_max_inx,:])

# %%
pairs = (['HEEH','Mean_res_entropy'],['EEHEE','exposed_np_AFILMVWY'])
f, ax = plt.subplots(1,2,figsize=[15,8])
for i in range(len(pairs)):
    top, fet = pairs[i]
    sns.kdeplot(data=stable_proteins[stable_proteins['topology']==top][fet],label='stable',shade=True,ax=ax[i])
    sns.kdeplot(data=unstable_proteins[unstable_proteins['topology']==top][fet],label='unstable',shade=True,ax=ax[i])
    ax[i].set_title("Distribution of %s between \nstable and unstable proteins in %s topology"%(fet,top))
    
plt.tight_layout()

# %% [markdown]
# ----------------------

# %% [markdown]
# # Change in Test Statistics Across 100 Iterations of Test Harness runs with Random Forest Classifier

# %% [markdown]
# ----------------------

# %% [markdown]
# **TODO**:
# - explain the Test Harness
# - explain why we want to look at TP and FP rates

# %%
def get_tptn_data(dataframe, 
                  real_value='stabilityscore_cnn_calibrated_2classes',
                 predicted_value='stabilityscore_cnn_calibrated_2classes_predictions',return_count=True):
    #get all 0's and all 1's
    positives = dataframe[dataframe['stabilityscore_cnn_calibrated_2classes']==1]
    negatives = dataframe[dataframe['stabilityscore_cnn_calibrated_2classes']==0]


    tp = positives[positives['stabilityscore_cnn_calibrated_2classes_predictions']==1]
    tn = negatives[negatives['stabilityscore_cnn_calibrated_2classes_predictions']==0]

    fp = negatives[negatives['stabilityscore_cnn_calibrated_2classes_predictions']==1]
    fn = positives[positives['stabilityscore_cnn_calibrated_2classes_predictions']==0]
    if return_count !=True:
        return tp,tn,fp,fn
    return len(tp),len(tn),len(fp),len(fn)

# %%
#load leaderboard
leaderboard = pd.read_html('./data/cross_val_tptn_classification_leaderboard.html')[0]

# %%
#get names of rosetta runs
rosetta_runs = leaderboard[leaderboard['Data and Split Description']=='R']
rosetta_runs_names = list(rosetta_runs['Run ID'].values)

# %%
#get names of R+S runs
entropy_rosetta_runs = leaderboard[leaderboard['Data and Split Description']=='RS']
entropy_rosetta_runs_names = list(entropy_rosetta_runs['Run ID'].values)

# %% [markdown]
# ### Rosetta Model TPTN data extraction

# %%
# "R" Model

#initialize dataframe that will contain data
ros_df = pd.DataFrame()
ros_df['TP Count'] = []
ros_df['FP Count'] = []
ros_df['TN Count'] = []
ros_df['FN Count'] = []

#initialize empty lists for data
ros_tp_data = []
ros_tn_data = []
ros_fp_data = []
ros_fn_data = []

#loop through files
for run_name in rosetta_runs_names:
    df = pd.read_csv('./test_harness_runs/tptn_runs/run_%s/testing_data.csv'%run_name)
    tp,tn,fp,fn = get_tptn_data(df)

    #update the lists
    ros_tp_data.append(tp)
    ros_tn_data.append(tn)
    ros_fp_data.append(fp)
    ros_fn_data.append(fn)

#construct final dataframe
ros_df['TP Count'] = ros_tp_data
ros_df['FP Count'] = ros_fp_data
ros_df['FN Count'] = ros_fn_data
ros_df['TN Count'] = ros_tn_data

# %%
ros_df.describe()

# %% [markdown]
# ### Rosetta+Entropy Model TPTN data extraction

# %%
# "R+S" Model

#initialize dataframe that will contain data
spc_df = pd.DataFrame()
spc_df['TP Count'] = []
spc_df['FP Count'] = []
spc_df['TN Count'] = []
spc_df['FN Count'] = []

#initialize empty lists for data
spc_tp_data = []
spc_tn_data = []
spc_fp_data = []
spc_fn_data = []

#loop through files
for run_name in entropy_rosetta_runs_names:
    df = pd.read_csv('./test_harness_runs/tptn_runs/run_%s/testing_data.csv'%run_name)
    tp,tn,fp,fn = get_tptn_data(df)

    #update the lists
    spc_tp_data.append(tp)
    spc_tn_data.append(tn)
    spc_fp_data.append(fp)
    spc_fn_data.append(fn)

#construct final dataframe
spc_df['TP Count'] = spc_tp_data
spc_df['FP Count'] = spc_fp_data
spc_df['FN Count'] = spc_fn_data
spc_df['TN Count'] = spc_tn_data

# %%
spc_df.describe()

# %%
results = spc_df.describe() - ros_df.describe()
results.iloc[1,:]
