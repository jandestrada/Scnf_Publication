# %% [markdown]
# ## TODO: add pictures

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import ks_2samp, epps_singleton_2samp

# %% [markdown]
# ----------------------

# %% [markdown]
# # Top-level view of SD2 protein design data

# %% [markdown]
# ----------------------

# %% [markdown]
# __TODO__:
# * explain why `NTF2` is dropped
# * explain what `stabilityscore_cnn_calibrated` means, and why we binarize
# * explain why S_pc is used as variable name

# %%
#show total number of entries, topologies used
data = pd.read_csv('./data/df_aggregated_spc.csv')

#NTF2 topology should not be used so remove those rows (stability score does not map equally to other topologies)
ntf2_inx = data[data['topology']=='NTF2'].index 
data = data.drop(ntf2_inx)

print("Total number of entries --> %s"%len(data))
print("Total number of topologies --> %s"%len(data.topology.unique()))
print("")

# define rosetta features
ros_features = pd.read_csv('./data/rosetta_features.csv')['0'].to_list()

# define entropy features
spc_features = pd.read_csv('./data/entropy_features.csv')["0"].to_list()

# define stability ('stable'/'unstable')
data['stabilityscore_cnn_calibrated_2classes'] = data['stabilityscore_cnn_calibrated'] > 1
stable_proteins = data[data['stabilityscore_cnn_calibrated_2classes']==1]
unstable_proteins = data[data['stabilityscore_cnn_calibrated_2classes']==0]


#get a list of topologies
topologies_list = list(data['topology'].unique())
# Out:
# Total number of entries --> 80257
# Total number of topologies --> 11

# %% [markdown]
# # Visualize Features for Classification

# %%
from HelperFunctions.feature_visualizations import show_all_plots

# %% [markdown]
# ## TODO:
# * add note explaining what is important to look at in these following plots

# %%
# show boxplot of all features (dataframe_visualizations/SD2 Feature Visualizations)
show_all_plots(data=data, 
               features=spc_features, 
               target='stabilityscore_cnn_calibrated_2classes',
               title_name='Distribution of entropy features across all protein topologies')
# Out:
# Number of Unstable: 68715
# number of Stable: 11542

# %% [markdown]
# ## TODO:
# * add notes explaining what specific plots one should pay attention to

# %%
#show plots for all features per topology

for topology in topologies_list:
    print("--------- Distributions for %s topology ----------"%topology)
    
    #subset the data to specify for a topology
    df = data[data['topology']==topology]
    
    #plot distributions for subset
    show_all_plots(data=df, 
               features=spc_features, 
               target='stabilityscore_cnn_calibrated_2classes',
               title_name='Distribution of entropy features across %s topology'%topology)
# Out:
# --------- Distributions for 4h topology ----------
# Number of Unstable: 13226
# number of Stable: 1466
# --------- Distributions for ferredoxin topology ----------
# Number of Unstable: 13263
# number of Stable: 1122
# --------- Distributions for beta_grasp topology ----------
# Number of Unstable: 2268
# number of Stable: 106
# --------- Distributions for thio topology ----------
# Number of Unstable: 1997
# number of Stable: 49
# --------- Distributions for fold2 topology ----------
# Number of Unstable: 582
# number of Stable: 75
# --------- Distributions for coil topology ----------
# Number of Unstable: 547
# number of Stable: 26
# --------- Distributions for fold4 topology ----------
# Number of Unstable: 237
# number of Stable: 18
# --------- Distributions for HHH topology ----------
# Number of Unstable: 7275
# number of Stable: 4741
# --------- Distributions for EEHEE topology ----------
# Number of Unstable: 9009
# number of Stable: 706
# --------- Distributions for EHEE topology ----------
# Number of Unstable: 5435
# number of Stable: 1210
# --------- Distributions for HEEH topology ----------
# Number of Unstable: 14876
# number of Stable: 2023

# %% [markdown]
# ----------------------

# %% [markdown]
# # Kolmogorov-Smirnov (KS) Test for 'stable' and 'unstable' distributions

# %% [markdown]
# ----------------------

# %% [markdown]
# ## TODO:
# * explain was `is_rosetta` column means
# * explain motivation for finding KS values

# %% [markdown]
# ## Topology-unspecified

# %%
from scipy.stats import ks_2samp

# get KS values for all features
rows = []
for fet in spc_features:
    subset_stable = stable_proteins[fet]
    subset_unstable = unstable_proteins[fet]
    
    ks_value, p_value = ks_2samp(subset_stable,subset_unstable)
    rows.append([fet,ks_value,False,p_value]) #third row corresponds to 'is_rosetta' column

for fet in ros_features:
    subset_stable = stable_proteins[fet]
    subset_unstable = unstable_proteins[fet]
    
    ks_value, p_value = ks_2samp(subset_stable,subset_unstable)
    rows.append([fet,ks_value,True,p_value])

    
    
#make a dataframe from ks value data
ks_values_all = pd.DataFrame(rows,columns=['Feature','KS','is_rosetta','P-value'])

#subset for entropy feature ks values and rosetta feature ks values
ks_values_all_spc = ks_values_all[ks_values_all['is_rosetta']==False]
ks_values_all_ros = ks_values_all[ks_values_all['is_rosetta']==True]


#get index of row with highest ks value for entropy and rosetta feature subset
spc_max_inx = ks_values_all_spc['KS'].idxmax()
ros_max_inx = ks_values_all_ros['KS'].idxmax()

# %%
print("Entropy feature with highest KS Value:\n",ks_values_all.iloc[spc_max_inx,:])
print()
print("Rosetta feature with highest KS Value\n",ks_values_all.iloc[ros_max_inx,:])
# Out:
# Entropy feature with highest KS Value:
#  Feature       E_max_entropy
# KS                 0.233719
# is_rosetta            False
# P-value                   0
# Name: 14, dtype: object
#
# Rosetta feature with highest KS Value
#  Feature       avg_best_frag
# KS                 0.361311
# is_rosetta             True
# P-value                   0
# Name: 27, dtype: object

# %% [markdown]
# ## TODO:
# * explain why `E_range_entropy` == `E_max_entropy`

# %%
# show entropy features ranked by KS value
ks_values_all_spc[ks_values_all_spc['P-value']<.05].sort_values(by='KS',ascending=False)
# Out:
#              Feature        KS  is_rosetta        P-value
# 16   E_range_entropy  0.233719       False   0.000000e+00
# 14     E_max_entropy  0.233719       False   0.000000e+00
# 15     E_min_entropy  0.233253       False   0.000000e+00
# 3     Mean_E_entropy  0.219145       False   0.000000e+00
# 7     SumE_entropies  0.219145       False   0.000000e+00
# 12     L_min_entropy  0.184505       False  1.264329e-292
# 2     Mean_L_entropy  0.161355       False  6.686678e-224
# 10   H_range_entropy  0.144643       False  5.250187e-180
# 8      H_max_entropy  0.135258       False  1.859491e-157
# 0               S_PC  0.105591       False   3.975463e-96
# 4   Mean_res_entropy  0.101095       False   3.761390e-88
# 13   L_range_entropy  0.092948       False   1.397498e-74
# 9      H_min_entropy  0.079753       False   5.071219e-55
# 5     SumH_entropies  0.076376       False   1.704570e-50
# 6     SumL_entropies  0.034517       False   1.187073e-10
# 11     L_max_entropy  0.031086       False   1.015233e-08
# 1     Mean_H_entropy  0.029384       False   7.764462e-08

# %% [markdown]
# ## Topology-specified

# %% [markdown]
# ## N.B.:
# * not all entropy features are showing for each topology because we are only showing those with p_value < .05
#
# * **IMPORTANT**: SciPy _needs_ to be version 1.3.0, since its `ks_2samp` function is more accurate than the 1.2.x version I was previously using

# %%
rows = []

for topology in topologies_list:
    stable_top_specific = stable_proteins[stable_proteins['topology']==topology]
    unstable_top_specific = unstable_proteins[unstable_proteins['topology']==topology]
    

    for fet in spc_features:
        subset_stable = stable_top_specific[fet]
        subset_unstable = unstable_top_specific[fet]

        ks_value, p_value = ks_2samp(subset_stable,subset_unstable)
        rows.append([fet,ks_value,False,topology,p_value]) #third row corresponds to 'is_rosetta' column

    for fet in ros_features:
        subset_stable = stable_top_specific[fet]
        subset_unstable = unstable_top_specific[fet]

        ks_value, p_value = ks_2samp(subset_stable,subset_unstable)
        rows.append([fet,ks_value,True,topology,p_value])

# %%
ks_values_topology = pd.DataFrame(rows,columns=['Feature','KS','is_rosetta','topology','P-value'])
ks_values_topology_spc = ks_values_topology[ks_values_topology['is_rosetta']==False].reset_index(drop=True)
ks_values_topology_ros = ks_values_topology[ks_values_topology['is_rosetta']==True].reset_index(drop=True)

# %%
#show entropy features ranked by KS value for each topology.
df = ks_values_topology_spc[ks_values_topology_spc['P-value']<.05].sort_values(by='KS',ascending=False)
for topology in topologies_list:
    print("\t TOPOLOGY --> %s"%topology)
    print(df[df['topology']==topology])
    print()
# Out:
# 	 TOPOLOGY --> 4h
#              Feature        KS  is_rosetta topology       P-value
# 5     SumH_entropies  0.115372       False       4h  1.104171e-15
# 1     Mean_H_entropy  0.114603       False       4h  1.760869e-15
# 0               S_PC  0.089316       False       4h  1.434538e-09
# 4   Mean_res_entropy  0.086368       False       4h  5.626970e-09
# 9      H_min_entropy  0.085904       False       4h  6.948911e-09
# 10   H_range_entropy  0.046820       False       4h  6.141417e-03
# 12     L_min_entropy  0.041484       False       4h  2.129706e-02
#
# 	 TOPOLOGY --> ferredoxin
#              Feature        KS  is_rosetta    topology       P-value
# 27   H_range_entropy  0.111798       False  ferredoxin  1.175939e-11
# 22    SumH_entropies  0.095049       False  ferredoxin  1.524946e-08
# 20    Mean_E_entropy  0.092258       False  ferredoxin  4.498617e-08
# 26     H_min_entropy  0.091111       False  ferredoxin  6.949401e-08
# 33   E_range_entropy  0.089613       False  ferredoxin  1.216890e-07
# 24    SumE_entropies  0.086504       False  ferredoxin  3.778487e-07
# 19    Mean_L_entropy  0.086114       False  ferredoxin  4.342707e-07
# 21  Mean_res_entropy  0.084972       False  ferredoxin  6.507108e-07
# 29     L_min_entropy  0.083986       False  ferredoxin  9.183743e-07
# 32     E_min_entropy  0.079926       False  ferredoxin  3.639007e-06
# 18    Mean_H_entropy  0.078884       False  ferredoxin  5.125204e-06
# 17              S_PC  0.077467       False  ferredoxin  8.105109e-06
# 23    SumL_entropies  0.065459       False  ferredoxin  2.824451e-04
# 25     H_max_entropy  0.053013       False  ferredoxin  5.967286e-03
# 28     L_max_entropy  0.047862       False  ferredoxin  1.748377e-02
# 31     E_max_entropy  0.044779       False  ferredoxin  3.156998e-02
#
# 	 TOPOLOGY --> beta_grasp
#            Feature        KS  is_rosetta    topology   P-value
# 39  SumH_entropies  0.139879       False  beta_grasp  0.034215
# 35  Mean_H_entropy  0.139871       False  beta_grasp  0.034230
#
# 	 TOPOLOGY --> thio
#            Feature        KS  is_rosetta topology   P-value
# 60   H_min_entropy  0.242353       False     thio  0.005852
# 52  Mean_H_entropy  0.198532       False     thio  0.039574
#
# 	 TOPOLOGY --> fold2
#              Feature        KS  is_rosetta topology   P-value
# 71    Mean_E_entropy  0.206254       False    fold2  0.005855
# 75    SumE_entropies  0.200275       False    fold2  0.008159
# 73    SumH_entropies  0.195601       False    fold2  0.010501
# 69    Mean_H_entropy  0.184399       False    fold2  0.018765
# 72  Mean_res_entropy  0.179381       False    fold2  0.024050
# 68              S_PC  0.178144       False    fold2  0.025542
#
# 	 TOPOLOGY --> coil
#              Feature        KS  is_rosetta topology   P-value
# 89  Mean_res_entropy  0.357826       False     coil  0.002385
# 85              S_PC  0.334130       False     coil  0.005648
# 90    SumH_entropies  0.288286       False     coil  0.025440
# 86    Mean_H_entropy  0.286458       False     coil  0.026873
#
# 	 TOPOLOGY --> fold4
#            Feature        KS  is_rosetta topology  P-value
# 110  H_max_entropy  0.336146       False    fold4  0.03459
#
# 	 TOPOLOGY --> HHH
# Empty DataFrame
# Columns: [Feature, KS, is_rosetta, topology, P-value]
# Index: []
#
# 	 TOPOLOGY --> EEHEE
#               Feature        KS  is_rosetta topology        P-value
# 143    SumE_entropies  0.421752       False    EEHEE  1.414491e-101
# 141    SumH_entropies  0.410102       False    EEHEE   4.588637e-96
# 137    Mean_H_entropy  0.409991       False    EEHEE   5.169506e-96
# 152   E_range_entropy  0.303562       False    EEHEE   7.928893e-53
# 144     H_max_entropy  0.274624       False    EEHEE   2.591900e-43
# 145     H_min_entropy  0.273839       False    EEHEE   4.555185e-43
# 151     E_min_entropy  0.264812       False    EEHEE   2.651936e-40
# 140  Mean_res_entropy  0.258531       False    EEHEE   1.962650e-38
# 139    Mean_E_entropy  0.250163       False    EEHEE   5.169702e-36
# 150     E_max_entropy  0.248600       False    EEHEE   1.434854e-35
# 148     L_min_entropy  0.222752       False    EEHEE   1.216008e-28
# 136              S_PC  0.159006       False    EEHEE   8.387494e-15
# 147     L_max_entropy  0.129361       False    EEHEE   6.093497e-10
# 149   L_range_entropy  0.123911       False    EEHEE   3.714489e-09
# 138    Mean_L_entropy  0.107039       False    EEHEE   6.104817e-07
# 142    SumL_entropies  0.096658       False    EEHEE   9.730536e-06
# 146   H_range_entropy  0.081575       False    EEHEE   3.287907e-04
#
# 	 TOPOLOGY --> EHEE
#             Feature        KS  is_rosetta topology       P-value
# 154  Mean_H_entropy  0.175689       False     EHEE  5.854359e-27
# 158  SumH_entropies  0.167024       False     EHEE  2.091536e-24
# 164   L_max_entropy  0.136030       False     EHEE  2.480836e-16
# 159  SumL_entropies  0.133068       False     EHEE  1.201709e-15
# 160  SumE_entropies  0.131479       False     EHEE  2.760484e-15
#
# 	 TOPOLOGY --> HEEH
#               Feature        KS  is_rosetta topology       P-value
# 174  Mean_res_entropy  0.208802       False     HEEH  7.299925e-68
# 175    SumH_entropies  0.185830       False     HEEH  7.681767e-54
# 170              S_PC  0.180820       False     HEEH  5.329771e-51
# 180   H_range_entropy  0.176285       False     HEEH  1.706404e-48
# 171    Mean_H_entropy  0.161161       False     HEEH  1.337477e-40
# 182     L_min_entropy  0.148002       False     HEEH  2.624720e-34
# 183   L_range_entropy  0.145385       False     HEEH  4.042000e-33
# 178     H_max_entropy  0.144721       False     HEEH  8.029688e-33
# 179     H_min_entropy  0.138382       False     HEEH  4.789943e-30
# 181     L_max_entropy  0.132154       False     HEEH  1.934352e-27
# 186   E_range_entropy  0.115818       False     HEEH  3.569837e-21
# 173    Mean_E_entropy  0.104341       False     HEEH  2.891003e-17
# 185     E_min_entropy  0.090990       False     HEEH  3.124920e-13
# 172    Mean_L_entropy  0.077403       False     HEEH  1.080969e-09
# 176    SumL_entropies  0.077128       False     HEEH  1.257751e-09
# 184     E_max_entropy  0.076853       False     HEEH  1.461829e-09
# 177    SumE_entropies  0.036162       False     HEEH  1.898156e-02

# %%
# Highest KS value for Entropy Feature in a topology:
spc_max_inx = ks_values_topology_spc['KS'].idxmax()

# %%
# Highest KS value for Rosetta Feature in a topology:
ros_max_inx = ks_values_topology_ros['KS'].idxmax()

# %%
print("Entropy feature with highest KS Value:\n",ks_values_topology_spc.iloc[spc_max_inx,:])
print()
print("Rosetta feature with highest KS Value\n",ks_values_topology_ros.iloc[ros_max_inx,:])
# Out:
# Entropy feature with highest KS Value:
#  Feature       SumE_entropies
# KS                  0.421752
# is_rosetta             False
# topology               EEHEE
# P-value         1.41449e-101
# Name: 143, dtype: object
#
# Rosetta feature with highest KS Value
#  Feature       contig_not_hp_avg
# KS                     0.648746
# is_rosetta                 True
# topology                  EEHEE
# P-value            9.29069e-240
# Name: 930, dtype: object

# %%
pairs = (['EEHEE','SumE_entropies'],['EEHEE','contig_not_hp_avg'])
f, ax = plt.subplots(1,2,figsize=[15,8])
for i in range(len(pairs)):
    top, fet = pairs[i]
    sns.kdeplot(data=stable_proteins[stable_proteins['topology']==top][fet],label='stable',shade=True,ax=ax[i])
    sns.kdeplot(data=unstable_proteins[unstable_proteins['topology']==top][fet],label='unstable',shade=True,ax=ax[i])
    ax[i].set_title("Distribution of %s between \nstable and unstable proteins in %s topology"%(fet,top))
    
plt.tight_layout()

# %% [markdown]
# ----------------------

# %% [markdown]
# # Epps-Singleton (ES) Test for 'stable' and 'unstable' distributions

# %% [markdown]
# ----------------------

# %% [markdown]
# ## TODO:
# * explain why ES test is better
# * explain motivation for finding ES values

# %% [markdown]
# ## Topology-unspecified

# %%
# get ES values for all features
rows = []
for fet in spc_features:
    try:
        subset_stable = stable_proteins[fet]
        subset_unstable = unstable_proteins[fet]

        es_value, p_value = epps_singleton_2samp(subset_stable,subset_unstable)
        rows.append([fet,es_value,False,p_value]) #third row corresponds to 'is_rosetta' column
    except:
        print("%s Feature did not work"%fet)
for fet in ros_features:
    try:
        subset_stable = stable_proteins[fet]
        subset_unstable = unstable_proteins[fet]
    
        es_value, p_value = epps_singleton_2samp(subset_stable,subset_unstable)
        rows.append([fet,es_value,True,p_value])
    except:
        print("%s Feature did not work"%fet)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:106: RuntimeWarning: divide by zero encountered in true_divide
#   ts = np.reshape(t, (-1, 1)) / sigma
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:109: RuntimeWarning: invalid value encountered in multiply
#   gx = np.vstack((np.cos(ts*x), np.sin(ts*x))).T  # shape = (nx, 2*len(t))
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:109: RuntimeWarning: invalid value encountered in cos
#   gx = np.vstack((np.cos(ts*x), np.sin(ts*x))).T  # shape = (nx, 2*len(t))
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:109: RuntimeWarning: invalid value encountered in sin
#   gx = np.vstack((np.cos(ts*x), np.sin(ts*x))).T  # shape = (nx, 2*len(t))
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:110: RuntimeWarning: invalid value encountered in multiply
#   gy = np.vstack((np.cos(ts*y), np.sin(ts*y))).T
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:110: RuntimeWarning: invalid value encountered in cos
#   gy = np.vstack((np.cos(ts*y), np.sin(ts*y))).T
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:110: RuntimeWarning: invalid value encountered in sin
#   gy = np.vstack((np.cos(ts*y), np.sin(ts*y))).T
# buns_sc_heavy Feature did not work
# dslf_fa13 Feature did not work
# entropy Feature did not work
# one_core_each Feature did not work
# ss_contributes_core Feature did not work

# %%
#make a dataframe from ES value data
es_values_all = pd.DataFrame(rows,columns=['Feature','ES','is_rosetta','P-value'])

#subset for entropy feature ks values and rosetta feature ks values
es_values_all_spc = es_values_all[es_values_all['is_rosetta']==False]
es_values_all_ros = es_values_all[es_values_all['is_rosetta']==True]


#get index of row with highest ks value for entropy and rosetta feature subset
spc_max_inx = es_values_all_spc['ES'].idxmax()
ros_max_inx = es_values_all_ros['ES'].idxmax()

# %%
print("Entropy feature with highest ES Value:\n",es_values_all.iloc[spc_max_inx,:])
print()
print("Rosetta feature with highest ES Value\n",es_values_all.iloc[ros_max_inx,:])
# Out:
# Entropy feature with highest ES Value:
#  Feature       E_range_entropy
# ES                    2390.42
# is_rosetta              False
# P-value                     0
# Name: 16, dtype: object
#
# Rosetta feature with highest ES Value
#  Feature       avg_all_frags
# ES                  9413.54
# is_rosetta             True
# P-value                   0
# Name: 26, dtype: object

# %%
# show entropy features ranked by ES value
es_values_all_spc[es_values_all_spc['P-value']<.05].sort_values(by='ES',ascending=False)
# Out:
#              Feature           ES  is_rosetta        P-value
# 16   E_range_entropy  2390.420981       False   0.000000e+00
# 14     E_max_entropy  2376.638167       False   0.000000e+00
# 7     SumE_entropies  2316.627892       False   0.000000e+00
# 3     Mean_E_entropy  2235.115909       False   0.000000e+00
# 15     E_min_entropy  2216.913063       False   0.000000e+00
# 12     L_min_entropy  1620.254269       False   0.000000e+00
# 2     Mean_L_entropy  1517.495319       False   0.000000e+00
# 8      H_max_entropy  1469.307465       False   0.000000e+00
# 10   H_range_entropy  1045.165785       False  5.809236e-225
# 13   L_range_entropy   551.330648       False  5.272611e-118
# 4   Mean_res_entropy   527.355132       False  8.109708e-113
# 5     SumH_entropies   520.936549       False  1.983740e-111
# 0               S_PC   506.286540       False  2.926532e-108
# 9      H_min_entropy   334.987092       False   3.055347e-71
# 1     Mean_H_entropy   214.723115       False   2.560609e-45
# 6     SumL_entropies   166.200922       False   6.834814e-35
# 11     L_max_entropy    58.386146       False   6.331647e-12

# %% [markdown]
# ## Topology-specified

# %% [markdown]
# ## N.B.:
# * not all entropy features are showing for each topology because we are only showing those with p_value < .05
#
# * **IMPORTANT**: SciPy _needs_ to be version 1.3.0, since its `epps_singleton_2samp` function is more accurate than the 1.2.x version I was previously using

# %%
rows = []

for topology in topologies_list:
    stable_top_specific = stable_proteins[stable_proteins['topology']==topology]
    unstable_top_specific = unstable_proteins[unstable_proteins['topology']==topology]
    
    #print("\t%s"%topology)
    for fet in spc_features:
        try:
            subset_stable = stable_top_specific[fet]
            subset_unstable = unstable_top_specific[fet]

            es_value, p_value = epps_singleton_2samp(subset_stable,subset_unstable)
            rows.append([fet,es_value,False,topology,p_value]) #third row corresponds to 'is_rosetta' column
        except:
            #print("%s Feature in %s topology did not work"%(fet,topology))
            pass
    print()
    for fet in ros_features:
        try:
            subset_stable = stable_top_specific[fet]
            subset_unstable = unstable_top_specific[fet]

            es_value, p_value = epps_singleton_2samp(subset_stable,subset_unstable)
            rows.append([fet,es_value,True,topology,p_value])
        except:
            #print("%s Feature in %s topology did not work"%(fet,topology))
            pass
    #print()
    #print()

es_values_topology = pd.DataFrame(rows,columns=['Feature','ES','is_rosetta','topology','P-value'])
es_values_topology_spc = es_values_topology[es_values_topology['is_rosetta']==False].reset_index(drop=True)
es_values_topology_ros = es_values_topology[es_values_topology['is_rosetta']==True].reset_index(drop=True)

#show entropy features ranked by KS value for each topology.
df = es_values_topology_spc[es_values_topology_spc['P-value']<.05].sort_values(by='ES',ascending=False)
for topology in topologies_list:
    print("\t TOPOLOGY --> %s"%topology)
    print(df[df['topology']==topology])
    print()
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:106: RuntimeWarning: divide by zero encountered in true_divide
#   ts = np.reshape(t, (-1, 1)) / sigma
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:109: RuntimeWarning: invalid value encountered in multiply
#   gx = np.vstack((np.cos(ts*x), np.sin(ts*x))).T  # shape = (nx, 2*len(t))
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:110: RuntimeWarning: invalid value encountered in multiply
#   gy = np.vstack((np.cos(ts*y), np.sin(ts*y))).T
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:109: RuntimeWarning: invalid value encountered in cos
#   gx = np.vstack((np.cos(ts*x), np.sin(ts*x))).T  # shape = (nx, 2*len(t))
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:109: RuntimeWarning: invalid value encountered in sin
#   gx = np.vstack((np.cos(ts*x), np.sin(ts*x))).T  # shape = (nx, 2*len(t))
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:110: RuntimeWarning: invalid value encountered in cos
#   gy = np.vstack((np.cos(ts*y), np.sin(ts*y))).T
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:110: RuntimeWarning: invalid value encountered in sin
#   gy = np.vstack((np.cos(ts*y), np.sin(ts*y))).T
# /usr/local/lib/python3.7/site-packages/scipy/stats/_hypotests.py:117: UserWarning: Estimated covariance matrix does not have full rank. This indicates a bad choice of the input t and the test might not be consistent.
#   warnings.warn('Estimated covariance matrix does not have full rank. '
# 	 TOPOLOGY --> 4h
#              Feature         ES  is_rosetta topology       P-value
# 4     SumH_entropies  91.425367       False       4h  6.556449e-19
# 1     Mean_H_entropy  79.799732       False       4h  1.920570e-16
# 0               S_PC  67.960659       False       4h  6.114407e-14
# 3   Mean_res_entropy  66.334295       False       4h  1.346789e-13
# 7      H_min_entropy  63.253925       False       4h  6.000139e-13
# 8    H_range_entropy  20.076963       False       4h  4.822277e-04
# 9      L_max_entropy  11.875199       False       4h  1.830385e-02
# 10     L_min_entropy   9.865373       False       4h  4.275755e-02
#
# 	 TOPOLOGY --> ferredoxin
#              Feature          ES  is_rosetta    topology       P-value
# 20     H_max_entropy  132.851903       False  ferredoxin  9.558789e-28
# 22   H_range_entropy  122.869011       False  ferredoxin  1.302440e-25
# 13    Mean_H_entropy   86.826664       False  ferredoxin  6.213592e-18
# 21     H_min_entropy   81.306557       False  ferredoxin  9.207775e-17
# 17    SumH_entropies   70.082571       False  ferredoxin  2.180537e-14
# 16  Mean_res_entropy   65.259674       False  ferredoxin  2.268645e-13
# 12              S_PC   51.644011       False  ferredoxin  1.637332e-10
# 15    Mean_E_entropy   48.988526       False  ferredoxin  5.871097e-10
# 28   E_range_entropy   47.742938       False  ferredoxin  1.067712e-09
# 14    Mean_L_entropy   42.581554       False  ferredoxin  1.263742e-08
# 27     E_min_entropy   38.896582       False  ferredoxin  7.317648e-08
# 19    SumE_entropies   37.834489       False  ferredoxin  1.212200e-07
# 24     L_min_entropy   35.309188       False  ferredoxin  4.013221e-07
# 18    SumL_entropies   30.790771       False  ferredoxin  3.377463e-06
# 23     L_max_entropy   19.716758       False  ferredoxin  5.679699e-04
# 26     E_max_entropy   12.759345       False  ferredoxin  1.251355e-02
#
# 	 TOPOLOGY --> beta_grasp
#              Feature         ES  is_rosetta    topology   P-value
# 38     H_min_entropy  26.139603       False  beta_grasp  0.000030
# 31    Mean_L_entropy  25.928222       False  beta_grasp  0.000033
# 30    Mean_H_entropy  25.200595       False  beta_grasp  0.000046
# 42   L_range_entropy  23.646067       False  beta_grasp  0.000094
# 33  Mean_res_entropy  23.398900       False  beta_grasp  0.000105
# 34    SumH_entropies  21.004238       False  beta_grasp  0.000316
# 37     H_max_entropy  20.404416       False  beta_grasp  0.000415
# 43     E_max_entropy  18.276004       False  beta_grasp  0.001090
# 35    SumL_entropies  16.865328       False  beta_grasp  0.002053
# 29              S_PC  14.821482       False  beta_grasp  0.005086
# 45   E_range_entropy  12.918920       False  beta_grasp  0.011679
#
# 	 TOPOLOGY --> thio
#              Feature         ES  is_rosetta topology       P-value
# 58     L_min_entropy  81.271876       False     thio  9.364933e-17
# 47    Mean_H_entropy  27.235708       False     thio  1.781250e-05
# 48    Mean_L_entropy  20.829276       False     thio  3.423279e-04
# 55     H_min_entropy  20.448644       False     thio  4.071866e-04
# 51    SumH_entropies  19.794726       False     thio  5.482154e-04
# 53    SumE_entropies  15.425332       False     thio  3.895676e-03
# 57     L_max_entropy  14.253298       False     thio  6.529006e-03
# 50  Mean_res_entropy  12.996873       False     thio  1.129108e-02
# 46              S_PC  10.935768       False     thio  2.729545e-02
# 52    SumL_entropies  10.339746       False     thio  3.507753e-02
#
# 	 TOPOLOGY --> fold2
#              Feature         ES  is_rosetta topology       P-value
# 63              S_PC  35.748344       False    fold2  3.259970e-07
# 67  Mean_res_entropy  32.452382       False    fold2  1.546123e-06
# 78     E_min_entropy  30.308074       False    fold2  4.236101e-06
# 70    SumE_entropies  28.880698       False    fold2  8.265958e-06
# 66    Mean_E_entropy  27.164522       False    fold2  1.841297e-05
# 74     L_max_entropy  24.559427       False    fold2  6.168462e-05
# 68    SumH_entropies  16.696380       False    fold2  2.213883e-03
# 64    Mean_H_entropy  16.332301       False    fold2  2.604191e-03
# 72     H_min_entropy  15.559177       False    fold2  3.671486e-03
# 77     E_max_entropy  10.736193       False    fold2  2.969443e-02
#
# 	 TOPOLOGY --> coil
#              Feature         ES  is_rosetta topology       P-value
# 91   L_range_entropy  42.257837       False     coil  1.474985e-08
# 88   H_range_entropy  39.927332       False     coil  4.480818e-08
# 90     L_min_entropy  32.935172       False     coil  1.231548e-06
# 87     H_min_entropy  16.001158       False     coil  3.017610e-03
# 83  Mean_res_entropy  15.456203       False     coil  3.842801e-03
# 80              S_PC  14.995431       False     coil  4.710702e-03
# 82    Mean_L_entropy  12.764070       False     coil  1.248802e-02
# 86     H_max_entropy  11.916544       False     coil  1.798278e-02
# 81    Mean_H_entropy  10.000963       False     coil  4.041147e-02
# 84    SumH_entropies   9.766246       False     coil  4.455480e-02
#
# 	 TOPOLOGY --> fold4
#               Feature         ES  is_rosetta topology       P-value
# 100     H_max_entropy  53.465781       False    fold4  6.808451e-11
# 98     SumL_entropies  34.404220       False    fold4  6.156590e-07
# 94     Mean_L_entropy  33.656435       False    fold4  8.764073e-07
# 102   H_range_entropy  28.391125       False    fold4  1.039112e-05
# 95     Mean_E_entropy  17.403618       False    fold4  1.613263e-03
# 99     SumE_entropies  14.068938       False    fold4  7.078252e-03
# 92               S_PC  11.438351       False    fold4  2.205513e-02
# 96   Mean_res_entropy  11.398983       False    fold4  2.242767e-02
# 105   L_range_entropy  10.245805       False    fold4  3.648455e-02
#
# 	 TOPOLOGY --> HHH
#               Feature          ES  is_rosetta topology       P-value
# 119     L_min_entropy  157.264042       False      HHH  5.644624e-33
# 116     H_min_entropy  113.698839       False      HHH  1.182796e-23
# 112  Mean_res_entropy  113.326039       False      HHH  1.420563e-23
# 114    SumL_entropies   88.994934       False      HHH  2.152696e-18
# 118     L_max_entropy   63.704669       False      HHH  4.822509e-13
# 109              S_PC   61.364096       False      HHH  1.498888e-12
# 111    Mean_L_entropy   51.267504       False      HHH  1.962616e-10
# 113    SumH_entropies   40.061756       False      HHH  4.202982e-08
# 120   L_range_entropy   34.079861       False      HHH  7.176077e-07
# 117   H_range_entropy   31.169936       False      HHH  2.826501e-06
# 110    Mean_H_entropy   27.195534       False      HHH  1.814894e-05
# 115     H_max_entropy   15.234284       False      HHH  4.239167e-03
#
# 	 TOPOLOGY --> EEHEE
#               Feature          ES  is_rosetta topology        P-value
# 128    SumE_entropies  728.376831       False    EEHEE  2.497455e-156
# 122    Mean_H_entropy  685.102862       False    EEHEE  5.858621e-147
# 126    SumH_entropies  684.419154       False    EEHEE  8.238128e-147
# 133     L_min_entropy  433.458991       False    EEHEE   1.634908e-92
# 125  Mean_res_entropy  359.801421       False    EEHEE   1.341388e-76
# 124    Mean_E_entropy  335.837599       False    EEHEE   2.002027e-71
# 130     H_min_entropy  325.428587       False    EEHEE   3.533188e-69
# 137   E_range_entropy  318.220010       False    EEHEE   1.270051e-67
# 129     H_max_entropy  302.290003       False    EEHEE   3.473902e-64
# 136     E_min_entropy  235.775818       False    EEHEE   7.534759e-50
# 134   L_range_entropy  227.633435       False    EEHEE   4.266118e-48
# 132     L_max_entropy  212.641193       False    EEHEE   7.181822e-45
# 135     E_max_entropy  201.642744       False    EEHEE   1.665994e-42
# 131   H_range_entropy  173.457985       False    EEHEE   1.893304e-36
# 121              S_PC  154.599879       False    EEHEE   2.102927e-32
# 127    SumL_entropies   79.165811       False    EEHEE   2.616410e-16
# 123    Mean_L_entropy   75.755008       False    EEHEE   1.379455e-15
#
# 	 TOPOLOGY --> EHEE
#               Feature          ES  is_rosetta topology       P-value
# 139    Mean_H_entropy  153.594898       False     EHEE  3.453481e-32
# 143    SumH_entropies  134.455665       False     EHEE  4.337953e-28
# 141    Mean_E_entropy  122.821065       False     EHEE  1.333529e-25
# 150     L_min_entropy   93.320826       False     EHEE  2.592973e-19
# 149     L_max_entropy   91.480505       False     EHEE  6.381927e-19
# 144    SumL_entropies   88.967265       False     EHEE  2.182021e-18
# 145    SumE_entropies   85.086589       False     EHEE  1.454130e-17
# 151   L_range_entropy   79.329842       False     EHEE  2.415259e-16
# 146     H_max_entropy   73.472317       False     EHEE  4.192247e-15
# 140    Mean_L_entropy   61.942499       False     EHEE  1.132705e-12
# 147     H_min_entropy   61.630801       False     EHEE  1.317283e-12
# 142  Mean_res_entropy   61.357455       False     EHEE  1.503715e-12
# 138              S_PC   43.457420       False     EHEE  8.316028e-09
# 154   E_range_entropy   42.305182       False     EHEE  1.442019e-08
# 148   H_range_entropy   41.025368       False     EHEE  2.655517e-08
# 153     E_min_entropy   30.201875       False     EHEE  4.452433e-06
# 152     E_max_entropy   27.001501       False     EHEE  1.986502e-05
#
# 	 TOPOLOGY --> HEEH
#               Feature          ES  is_rosetta topology        P-value
# 159  Mean_res_entropy  950.207758       False     HEEH  2.201450e-204
# 160    SumH_entropies  674.972177       False     HEEH  9.145234e-145
# 156    Mean_H_entropy  656.478486       False     HEEH  9.226131e-141
# 155              S_PC  613.350670       False     HEEH  1.998421e-131
# 164     H_min_entropy  441.637219       False     HEEH   2.790579e-94
# 165   H_range_entropy  390.808847       False     HEEH   2.692082e-83
# 168   L_range_entropy  323.761568       False     HEEH   8.089815e-69
# 171   E_range_entropy  305.934807       False     HEEH   5.682371e-65
# 167     L_min_entropy  256.482057       False     HEEH   2.612338e-54
# 158    Mean_E_entropy  245.945249       False     HEEH   4.863999e-52
# 169     E_max_entropy  238.073695       False     HEEH   2.411396e-50
# 163     H_max_entropy  218.308852       False     HEEH   4.333484e-46
# 170     E_min_entropy  178.498647       False     HEEH   1.566590e-37
# 166     L_max_entropy  165.094571       False     HEEH   1.180597e-34
# 157    Mean_L_entropy  120.801718       False     HEEH   3.600930e-25
# 161    SumL_entropies   73.816532       False     HEEH   3.545502e-15
# 162    SumE_entropies   17.879502       False     HEEH   1.302840e-03

# %%
# Highest KS value for Entropy Feature in a topology:
spc_max_inx = es_values_topology_spc['ES'].idxmax()

# Highest KS value for Rosetta Feature in a topology:
ros_max_inx = es_values_topology_ros['ES'].idxmax()

print("Entropy feature with highest ES Value:\n",es_values_topology_spc.iloc[spc_max_inx,:])
print()
print("Rosetta feature with highest ES Value\n",es_values_topology_ros.iloc[ros_max_inx,:])
# Out:
# Entropy feature with highest ES Value:
#  Feature       Mean_res_entropy
# ES                     950.208
# is_rosetta               False
# topology                  HEEH
# P-value           2.20145e-204
# Name: 159, dtype: object
#
# Rosetta feature with highest ES Value
#  Feature       exposed_np_AFILMVWY
# ES                        4912.56
# is_rosetta                   True
# topology                    EEHEE
# P-value                         0
# Name: 890, dtype: object

# %%
pairs = (['HEEH','Mean_res_entropy'],['EEHEE','exposed_np_AFILMVWY'])
f, ax = plt.subplots(1,2,figsize=[15,8])
for i in range(len(pairs)):
    top, fet = pairs[i]
    sns.kdeplot(data=stable_proteins[stable_proteins['topology']==top][fet],label='stable',shade=True,ax=ax[i])
    sns.kdeplot(data=unstable_proteins[unstable_proteins['topology']==top][fet],label='unstable',shade=True,ax=ax[i])
    ax[i].set_title("Distribution of %s between \nstable and unstable proteins in %s topology"%(fet,top))
    
plt.tight_layout()

# %% [markdown]
# ----------------------

# %% [markdown]
# # Change in Test Statistics Across 100 Iterations of Test Harness runs with Random Forest Classifier

# %% [markdown]
# ----------------------

# %% [markdown]
# **TODO**:
# - explain the Test Harness
# - explain why we want to look at TP and FP rates

# %%
def get_tptn_data(dataframe, 
                  real_value='stabilityscore_cnn_calibrated_2classes',
                 predicted_value='stabilityscore_cnn_calibrated_2classes_predictions',return_count=True):
    #get all 0's and all 1's
    positives = dataframe[dataframe['stabilityscore_cnn_calibrated_2classes']==1]
    negatives = dataframe[dataframe['stabilityscore_cnn_calibrated_2classes']==0]


    tp = positives[positives['stabilityscore_cnn_calibrated_2classes_predictions']==1]
    tn = negatives[negatives['stabilityscore_cnn_calibrated_2classes_predictions']==0]

    fp = negatives[negatives['stabilityscore_cnn_calibrated_2classes_predictions']==1]
    fn = positives[positives['stabilityscore_cnn_calibrated_2classes_predictions']==0]
    if return_count !=True:
        return tp,tn,fp,fn
    return len(tp),len(tn),len(fp),len(fn)

# %%
#load leaderboard
leaderboard = pd.read_html('./data/cross_val_tptn_classification_leaderboard.html')[0]

# %%
#get names of rosetta runs
rosetta_runs = leaderboard[leaderboard['Data and Split Description']=='R']
rosetta_runs_names = list(rosetta_runs['Run ID'].values)

# %%
#get names of R+S runs
entropy_rosetta_runs = leaderboard[leaderboard['Data and Split Description']=='RS']
entropy_rosetta_runs_names = list(entropy_rosetta_runs['Run ID'].values)

# %% [markdown]
# ### Rosetta Model TPTN data extraction

# %%
# "R" Model

#initialize dataframe that will contain data
ros_df = pd.DataFrame()
ros_df['TP Count'] = []
ros_df['FP Count'] = []
ros_df['TN Count'] = []
ros_df['FN Count'] = []

#initialize empty lists for data
ros_tp_data = []
ros_tn_data = []
ros_fp_data = []
ros_fn_data = []

#loop through files
for run_name in rosetta_runs_names:
    df = pd.read_csv('./runs/run_%s/testing_data.csv'%run_name)
    tp,tn,fp,fn = get_tptn_data(df)

    #update the lists
    ros_tp_data.append(tp)
    ros_tn_data.append(tn)
    ros_fp_data.append(fp)
    ros_fn_data.append(fn)

#construct final dataframe
ros_df['TP Count'] = ros_tp_data
ros_df['FP Count'] = ros_fp_data
ros_df['FN Count'] = ros_fn_data
ros_df['TN Count'] = ros_tn_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-28cd17c68ade> in <module>
#      16 #loop through files
#      17 for run_name in rosetta_runs_names:
# ---> 18     df = pd.read_csv('./runs/run_%s/testing_data.csv'%run_name)
#      19     tp,tn,fp,fn = get_tptn_data(df)
#      20
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./runs/run_ERV6VXAY3jGXP/testing_data.csv' does not exist: b'./runs/run_ERV6VXAY3jGXP/testing_data.csv'

# %%
ros_df.describe()

# %% [markdown]
# ### Rosetta+Entropy Model TPTN data extraction

# %%
# "R+S" Model

#initialize dataframe that will contain data
spc_df = pd.DataFrame()
spc_df['TP Count'] = []
spc_df['FP Count'] = []
spc_df['TN Count'] = []
spc_df['FN Count'] = []

#initialize empty lists for data
spc_tp_data = []
spc_tn_data = []
spc_fp_data = []
spc_fn_data = []

#loop through files
for run_name in entropy_rosetta_runs_names:
    df = pd.read_csv('./runs/run_%s/testing_data.csv'%run_name)
    tp,tn,fp,fn = get_tptn_data(df)

    #update the lists
    spc_tp_data.append(tp)
    spc_tn_data.append(tn)
    spc_fp_data.append(fp)
    spc_fn_data.append(fn)

#construct final dataframe
spc_df['TP Count'] = spc_tp_data
spc_df['FP Count'] = spc_fp_data
spc_df['FN Count'] = spc_fn_data
spc_df['TN Count'] = spc_tn_data

# %%
spc_df.describe()

# %%
results = spc_df.describe() - ros_df.describe()
results.iloc[1,:]
